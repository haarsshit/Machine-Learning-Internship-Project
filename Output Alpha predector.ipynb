# %%
import numpy as np
import pandas as pd

# %%
d=pd.read_csv('/Users/khars/OneDrive/Desktop/ml intern/D2D_myfile1multi.csv')

# %%
d.head()
# Out:
#       T_1      T_2        D         d   mbc1   mbc2   mtr1   mtr2   mtc1   \
# 0  0.87031  0.79774  0.56349  0.187010      4      1      2      3      5
# 1  0.70150  0.31756  0.58067  0.182960      5      4      2      3      4
# 2  0.41306  0.10463  0.68317  0.114490      3      1      2      2      5
# 3  0.61549  0.11504  0.66143  0.099048      3      3      4      3      5
# 4  0.67304  0.33087  0.57214  0.177930      5      1      5      2      5
#
#    mtc2   mbr1   mbr2  Output Alpha  Output Power1  Output Power2
# 0      5      1     5       0.66260       0.100000        1.00000
# 1      2      1     2       0.76016       0.100000        1.00000
# 2      4      2     2       0.82574       0.026296        0.26296
# 3      3      4     1       0.87410       0.038920        0.38920
# 4      3      5     4       0.74362       0.100000        1.00000

# %%
D=d.drop("Output Power1",axis=1)

# %%
D.head()
# Out:
#       T_1      T_2        D         d   mbc1   mbc2   mtr1   mtr2   mtc1   \
# 0  0.87031  0.79774  0.56349  0.187010      4      1      2      3      5
# 1  0.70150  0.31756  0.58067  0.182960      5      4      2      3      4
# 2  0.41306  0.10463  0.68317  0.114490      3      1      2      2      5
# 3  0.61549  0.11504  0.66143  0.099048      3      3      4      3      5
# 4  0.67304  0.33087  0.57214  0.177930      5      1      5      2      5
#
#    mtc2   mbr1   mbr2  Output Alpha  Output Power2
# 0      5      1     5       0.66260        1.00000
# 1      2      1     2       0.76016        1.00000
# 2      4      2     2       0.82574        0.26296
# 3      3      4     1       0.87410        0.38920
# 4      3      5     4       0.74362        1.00000

# %%
E=D.drop("Output Power2",axis=1)

# %%
E.head()
# Out:
#       T_1      T_2        D         d   mbc1   mbc2   mtr1   mtr2   mtc1   \
# 0  0.87031  0.79774  0.56349  0.187010      4      1      2      3      5
# 1  0.70150  0.31756  0.58067  0.182960      5      4      2      3      4
# 2  0.41306  0.10463  0.68317  0.114490      3      1      2      2      5
# 3  0.61549  0.11504  0.66143  0.099048      3      3      4      3      5
# 4  0.67304  0.33087  0.57214  0.177930      5      1      5      2      5
#
#    mtc2   mbr1   mbr2  Output Alpha
# 0      5      1     5       0.66260
# 1      2      1     2       0.76016
# 2      4      2     2       0.82574
# 3      3      4     1       0.87410
# 4      3      5     4       0.74362

# %%
E.corr()
# Out:
#                   T_1       T_2         D         d      mbc1      mbc2   \
# T_1           1.000000  0.515053  0.002820  0.002606 -0.006326 -0.000708
# T_2           0.515053  1.000000 -0.000609 -0.002437 -0.001749  0.001664
# D             0.002820 -0.000609  1.000000 -0.002571 -0.003914  0.000547
# d             0.002606 -0.002437 -0.002571  1.000000 -0.002006  0.001401
# mbc1         -0.006326 -0.001749 -0.003914 -0.002006  1.000000 -0.000663
# mbc2         -0.000708  0.001664  0.000547  0.001401 -0.000663  1.000000
# mtr1          0.002591  0.000401  0.004990  0.002984  0.002255 -0.004519
# mtr2         -0.001321  0.004656 -0.001926 -0.002848 -0.001698  0.003421
# mtc1         -0.001544  0.001441  0.001291 -0.002008  0.000435  0.000036
# mtc2          0.000145 -0.002626  0.005214 -0.001899  0.002405 -0.009301
# mbr1         -0.006603  0.000675  0.001856  0.001782 -0.000473  0.002459
# mbr2          0.004661  0.005444  0.001916 -0.001618  0.009188  0.001501
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#get correlations of each features in dataset
corrmat = E.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(E[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
from sklearn.model_selection import train_test_split

# %%
X=E.iloc[:,:-2]

# %%
Y=E.iloc[:,-1:]

# %%
X.head()
# Out:
#       T_1      T_2        D         d   mbc1   mbc2   mtr1   mtr2   mtc1   \
# 0  0.87031  0.79774  0.56349  0.187010      4      1      2      3      5
# 1  0.70150  0.31756  0.58067  0.182960      5      4      2      3      4
# 2  0.41306  0.10463  0.68317  0.114490      3      1      2      2      5
# 3  0.61549  0.11504  0.66143  0.099048      3      3      4      3      5
# 4  0.67304  0.33087  0.57214  0.177930      5      1      5      2      5
#
#    mtc2   mbr1
# 0      5      1
# 1      2      1
# 2      4      2
# 3      3      4
# 4      3      5

# %%
Y.head()
# Out:
#    Output Alpha
# 0       0.66260
# 1       0.76016
# 2       0.82574
# 3       0.87410
# 4       0.74362

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=0)

# %%
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import GradientBoostingRegressor
MultiOutputRegressor(GradientBoostingRegressor(random_state=0)).fit(X_train, Y_train)
# Out:
# MultiOutputRegressor(estimator=GradientBoostingRegressor(random_state=0))

# %%
mult_reg = MultiOutputRegressor(GradientBoostingRegressor(random_state=0)).fit(X_train, Y_train)

# %%
y_pred = mult_reg.predict(X_test)

# %%
y_pred
# Out:
# array([[0.70962707],
#        [0.70334331],
#        [0.79498779],
#        ...,
#        [0.89246313],
#        [0.84707533],
#        [0.66546317]])

# %%
from sklearn.metrics import mean_squared_error

# %%
train_pred = mult_reg.predict(X_train)

# %%
train_score = mean_squared_error(Y_train,train_pred)

# %%
train_score
# Out:
# 0.0003571230689134979
